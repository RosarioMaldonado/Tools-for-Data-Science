# %% [markdown]
# <a href="https://colab.research.google.com/github/RosarioMaldonado/Tools-for-Data-Science/blob/main/Peer_graded_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercise 2 - Create a markdown cell with the title of the notebook

# %% [markdown]
# #**Data Science Tools and Ecosystem**

# %% [markdown]
# Exercise 3 - Create a markdown cell for an introduction

# %% [markdown]
# Data science is the process of extracting insights and knowledge from data through the use of statistical, computational, and visualization techniques. Data science tools and ecosystem are the software and hardware technologies that enable data scientists to perform these tasks efficiently and effectively.

# %% [markdown]
# Exercise 4 - Create a markdown cell to list data science languages.

# %% [markdown]
# *   Python
# *   R
# *   SQL
# *   Java
# *   Scala
# *   C++
# *   Julia
# *   JavaScript
# *   PHP
# *   Go
# *   Ruby
# *   Visual Basic

# %% [markdown]
# Exercise 5 - Create a markdown cell to list data science libraries.

# %% [markdown]
# *   NumPy
# *   Pandas
# *   Matplotlib
# *   Scikit-learn
# *   TensorFlow
# *   PyTorch
# *   Seaborn
# *   Keras
# *   Apache Spark
# *   Vegas
# *   Big DL
# *   Ggplot2

# %% [markdown]
# Exercise 6 - Create a markdown cell with a table of Data Science Tools.

# %% [markdown]
# *   Anaconda
# *   Jupyter Notebooks
# *   R studio
# *   Spyder
# *   Zeppelin

# %% [markdown]
# Exercise 7 - Create a markdown cell introducing arithmetic expression examples.

# %%
print(3 + 4)
print(3 - 4)
print(3 * 4)
print(3 / 4)
print(10 % 3)
print(10 // 3)
# Out:
# 7
# -1
# 12
# 0.75
# 1
# 3

# %% [markdown]
# Exercise 8 - Create a code cell to multiply and add numbers.

# %%
a = 5
b = 10
c = a + b 
d = a * b
print(c)
print(d)
# Out:
# 15
# 50

# %% [markdown]
# Exercise 9 - Create a code cell to convert minutes to hours

# %%
minutes = 120
hours = minutes / 60
print(hours)
# Out:
# 2.0

# %% [markdown]
# Exercise 10 -Insert a markdown cell to list Objectives

# %% [markdown]
# *   Create markdown cells.
# *   Add comments to code.
# *   Format content of markdown cells with heading styles.
# *   Add ordered and ordered lists to markdown cells.

# %% [markdown]
# Exercise 11 - Create a markdown cell to indicate the Author’s name.

# %% [markdown]
# # **Author**
#
# *Rosario Maldonado*

# %% [markdown]
# Exercise 13 - Take a screenshot of the first page of the notebook.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
